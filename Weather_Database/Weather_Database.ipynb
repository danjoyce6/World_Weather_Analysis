# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 793

# %%
# Import the requests library.
import requests
# Import the API key.
from configure import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        for d in city_weather["weather"]:
            city_description = d['description']
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country, "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olafsvik
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | toma
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | soe
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | uglegorsk
# Processing Record 15 of Set 1 | aklavik
# Processing Record 16 of Set 1 | mareeba
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | borohradek
# Processing Record 19 of Set 1 | dubti
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | irara
# Processing Record 24 of Set 1 | casablanca
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | general roca
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | staunton
# Processing Record 33 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | kashary
# Processing Record 36 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | san andres
# Processing Record 41 of Set 1 | te anau
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | denizli
# Processing Record 45 of Set 1 | porto nacional
# Processing Record 46 of Set 1 | moses lake
# Processing Record 47 of Set 1 | tlahualilo
# City not found. Skipping...
# Processing Record 48 of Set 1 | sao paulo de olivenca
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | price
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | leonidion
# City not found. Skipping...
# Processing Record 5 of Set 2 | ust-kuyga
# Processing Record 6 of Set 2 | dunedin
# Processing Record 7 of Set 2 | bam
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | batagay-alyta
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | kungalv
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | qaqortoq
# Processing Record 16 of Set 2 | north platte
# Processing Record 17 of Set 2 | vao
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | aswan
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | nampula
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | plainview
# Processing Record 27 of Set 2 | salalah
# Processing Record 28 of Set 2 | padang
# Processing Record 29 of Set 2 | kudahuvadhoo
# Processing Record 30 of Set 2 | muriwai beach
# Processing Record 31 of Set 2 | college
# Processing Record 32 of Set 2 | tonota
# Processing Record 33 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 2 | vardo
# Processing Record 35 of Set 2 | maningrida
# Processing Record 36 of Set 2 | pala
# Processing Record 37 of Set 2 | bako
# Processing Record 38 of Set 2 | quzhou
# Processing Record 39 of Set 2 | green river
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | miri
# Processing Record 44 of Set 2 | high level
# Processing Record 45 of Set 2 | borger
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | nantucket
# Processing Record 48 of Set 2 | riyadh
# Processing Record 49 of Set 2 | acajutla
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | nishihara
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | vyazemskiy
# Processing Record 4 of Set 3 | bagdarin
# Processing Record 5 of Set 3 | anshun
# Processing Record 6 of Set 3 | ati
# Processing Record 7 of Set 3 | boa vista
# Processing Record 8 of Set 3 | fond du lac
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | palora
# Processing Record 11 of Set 3 | saint-joseph
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | izhma
# Processing Record 14 of Set 3 | rio grande
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | juntas
# Processing Record 18 of Set 3 | jizan
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | greytown
# Processing Record 21 of Set 3 | vila franca do campo
# Processing Record 22 of Set 3 | bakreswar
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | itarema
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | lubango
# Processing Record 30 of Set 3 | daud khel
# Processing Record 31 of Set 3 | bilma
# Processing Record 32 of Set 3 | korla
# Processing Record 33 of Set 3 | rio gallegos
# Processing Record 34 of Set 3 | axim
# Processing Record 35 of Set 3 | sisimiut
# Processing Record 36 of Set 3 | plettenberg bay
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | huron
# Processing Record 39 of Set 3 | shimoda
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | madang
# Processing Record 46 of Set 3 | yaan
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | ossora
# Processing Record 50 of Set 3 | dali
# Processing Record 1 of Set 4 | cuenca
# Processing Record 2 of Set 4 | bogorodskoye
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | tubuala
# Processing Record 5 of Set 4 | zyryanka
# Processing Record 6 of Set 4 | lasa
# Processing Record 7 of Set 4 | beringovskiy
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | leeton
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | alice springs
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | iskateley
# Processing Record 17 of Set 4 | ostrovnoy
# Processing Record 18 of Set 4 | calbuco
# Processing Record 19 of Set 4 | novobirilyussy
# Processing Record 20 of Set 4 | raudeberg
# Processing Record 21 of Set 4 | el tarra
# Processing Record 22 of Set 4 | shuangyang
# Processing Record 23 of Set 4 | mehamn
# Processing Record 24 of Set 4 | pauini
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | la paz
# Processing Record 27 of Set 4 | ixtapa
# Processing Record 28 of Set 4 | bundaberg
# Processing Record 29 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 4 | road town
# Processing Record 31 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 4 | sheridan
# Processing Record 33 of Set 4 | egvekinot
# Processing Record 34 of Set 4 | tabou
# Processing Record 35 of Set 4 | san luis
# Processing Record 36 of Set 4 | bagotville
# Processing Record 37 of Set 4 | umm lajj
# Processing Record 38 of Set 4 | iquitos
# Processing Record 39 of Set 4 | suntar
# Processing Record 40 of Set 4 | skelleftea
# Processing Record 41 of Set 4 | nouakchott
# Processing Record 42 of Set 4 | deputatskiy
# Processing Record 43 of Set 4 | banda aceh
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | kurilsk
# Processing Record 46 of Set 4 | tokomaru
# Processing Record 47 of Set 4 | new norfolk
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | coolum beach
# Processing Record 50 of Set 4 | port macquarie
# Processing Record 1 of Set 5 | ahuimanu
# Processing Record 2 of Set 5 | bambanglipuro
# Processing Record 3 of Set 5 | chaves
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | castro
# Processing Record 6 of Set 5 | portland
# Processing Record 7 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 5 | jiuquan
# Processing Record 9 of Set 5 | kikwit
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | paris
# Processing Record 12 of Set 5 | hidrolandia
# Processing Record 13 of Set 5 | kupang
# Processing Record 14 of Set 5 | sioux lookout
# Processing Record 15 of Set 5 | atbasar
# Processing Record 16 of Set 5 | poya
# Processing Record 17 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 5 | natitingou
# Processing Record 19 of Set 5 | rawson
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | pemangkat
# Processing Record 23 of Set 5 | bonavista
# Processing Record 24 of Set 5 | upata
# Processing Record 25 of Set 5 | dawson creek
# Processing Record 26 of Set 5 | sile
# Processing Record 27 of Set 5 | coahuayana
# Processing Record 28 of Set 5 | wyndham
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | racine
# Processing Record 31 of Set 5 | acarau
# Processing Record 32 of Set 5 | urucara
# Processing Record 33 of Set 5 | bloomington
# Processing Record 34 of Set 5 | el chol
# Processing Record 35 of Set 5 | muros
# Processing Record 36 of Set 5 | alvdal
# Processing Record 37 of Set 5 | frontera
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | fairbanks
# Processing Record 40 of Set 5 | fenyi
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | gat
# Processing Record 43 of Set 5 | faya
# Processing Record 44 of Set 5 | madingou
# Processing Record 45 of Set 5 | jelenia gora
# Processing Record 46 of Set 5 | olinda
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | ibra
# Processing Record 49 of Set 5 | longyearbyen
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | kruisfontein
# Processing Record 2 of Set 6 | balkanabat
# Processing Record 3 of Set 6 | labrea
# Processing Record 4 of Set 6 | anloga
# Processing Record 5 of Set 6 | black river
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | birin
# Processing Record 8 of Set 6 | sishui
# Processing Record 9 of Set 6 | uray
# Processing Record 10 of Set 6 | ulagan
# Processing Record 11 of Set 6 | kavieng
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | barrow
# Processing Record 14 of Set 6 | clyde river
# Processing Record 15 of Set 6 | gravdal
# Processing Record 16 of Set 6 | girua
# Processing Record 17 of Set 6 | stribro
# Processing Record 18 of Set 6 | cozumel
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | bonfim
# Processing Record 21 of Set 6 | boyolangu
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | los llanos de aridane
# Processing Record 24 of Set 6 | takoradi
# Processing Record 25 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 6 | flinders
# Processing Record 27 of Set 6 | dudinka
# Processing Record 28 of Set 6 | namatanai
# Processing Record 29 of Set 6 | udachnyy
# Processing Record 30 of Set 6 | provideniya
# Processing Record 31 of Set 6 | mandali
# Processing Record 32 of Set 6 | brownsville
# Processing Record 33 of Set 6 | anjozorobe
# Processing Record 34 of Set 6 | uyuni
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | shelburne
# Processing Record 37 of Set 6 | flin flon
# Processing Record 38 of Set 6 | rincon
# Processing Record 39 of Set 6 | bud
# Processing Record 40 of Set 6 | kalmunai
# Processing Record 41 of Set 6 | port elizabeth
# Processing Record 42 of Set 6 | wajima
# Processing Record 43 of Set 6 | ormara
# Processing Record 44 of Set 6 | saint george
# Processing Record 45 of Set 6 | vostok
# Processing Record 46 of Set 6 | pringsewu
# Processing Record 47 of Set 6 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 48 of Set 6 | dicabisagan
# Processing Record 49 of Set 6 | havre
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | urbano santos
# Processing Record 2 of Set 7 | belaya gora
# Processing Record 3 of Set 7 | champasak
# Processing Record 4 of Set 7 | ola
# Processing Record 5 of Set 7 | nabire
# Processing Record 6 of Set 7 | kushiro
# Processing Record 7 of Set 7 | ponta do sol
# Processing Record 8 of Set 7 | labuhan
# Processing Record 9 of Set 7 | fianga
# City not found. Skipping...
# Processing Record 10 of Set 7 | osoyoos
# Processing Record 11 of Set 7 | saint-georges
# Processing Record 12 of Set 7 | uruzgan
# Processing Record 13 of Set 7 | panama city
# Processing Record 14 of Set 7 | indian head
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | warrnambool
# Processing Record 17 of Set 7 | the pas
# Processing Record 18 of Set 7 | haines junction
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | marrakesh
# Processing Record 21 of Set 7 | mwinilunga
# Processing Record 22 of Set 7 | rantoul
# Processing Record 23 of Set 7 | omsukchan
# Processing Record 24 of Set 7 | safford
# Processing Record 25 of Set 7 | sangar
# Processing Record 26 of Set 7 | mattru
# Processing Record 27 of Set 7 | pangnirtung
# Processing Record 28 of Set 7 | srikakulam
# Processing Record 29 of Set 7 | sinnamary
# Processing Record 30 of Set 7 | nanortalik
# Processing Record 31 of Set 7 | santa teresa
# Processing Record 32 of Set 7 | santa rosalia
# Processing Record 33 of Set 7 | channel-port aux basques
# Processing Record 34 of Set 7 | bambous virieux
# Processing Record 35 of Set 7 | terrace
# Processing Record 36 of Set 7 | oga
# Processing Record 37 of Set 7 | merauke
# Processing Record 38 of Set 7 | ambovombe
# Processing Record 39 of Set 7 | pisco
# Processing Record 40 of Set 7 | ayoquezco
# City not found. Skipping...
# Processing Record 41 of Set 7 | pevek
# Processing Record 42 of Set 7 | yumen
# Processing Record 43 of Set 7 | itigi
# Processing Record 44 of Set 7 | davila
# Processing Record 45 of Set 7 | puerto escondido
# Processing Record 46 of Set 7 | mount isa
# Processing Record 47 of Set 7 | mokhsogollokh
# Processing Record 48 of Set 7 | alpena
# Processing Record 49 of Set 7 | macapa
# Processing Record 50 of Set 7 | kulevcha
# Processing Record 1 of Set 8 | khorinsk
# Processing Record 2 of Set 8 | paciran
# Processing Record 3 of Set 8 | silver city
# Processing Record 4 of Set 8 | muroto
# Processing Record 5 of Set 8 | boende
# Processing Record 6 of Set 8 | san joaquin
# Processing Record 7 of Set 8 | kargasok
# Processing Record 8 of Set 8 | sayyan
# Processing Record 9 of Set 8 | alihe
# Processing Record 10 of Set 8 | hangha
# Processing Record 11 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | altos
# Processing Record 13 of Set 8 | biharamulo
# Processing Record 14 of Set 8 | henties bay
# Processing Record 15 of Set 8 | samarai
# Processing Record 16 of Set 8 | launceston
# Processing Record 17 of Set 8 | tarbagatay
# Processing Record 18 of Set 8 | nalut
# Processing Record 19 of Set 8 | shenzhen
# Processing Record 20 of Set 8 | half moon bay
# Processing Record 21 of Set 8 | asau
# Processing Record 22 of Set 8 | ak-dovurak
# Processing Record 23 of Set 8 | gizo
# Processing Record 24 of Set 8 | acapulco
# Processing Record 25 of Set 8 | coquimbo
# Processing Record 26 of Set 8 | sarakhs
# Processing Record 27 of Set 8 | klaksvik
# Processing Record 28 of Set 8 | coihueco
# Processing Record 29 of Set 8 | havelock
# Processing Record 30 of Set 8 | ayan
# Processing Record 31 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 8 | grand-santi
# Processing Record 33 of Set 8 | manavalakurichi
# Processing Record 34 of Set 8 | harbour breton
# Processing Record 35 of Set 8 | ghanzi
# Processing Record 36 of Set 8 | adrar
# Processing Record 37 of Set 8 | karratha
# Processing Record 38 of Set 8 | bang saphan
# Processing Record 39 of Set 8 | krasnovishersk
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | tevaitoa
# Processing Record 42 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 8 | saint anthony
# Processing Record 44 of Set 8 | kroya
# Processing Record 45 of Set 8 | begowala
# Processing Record 46 of Set 8 | kodiak
# Processing Record 47 of Set 8 | aberystwyth
# Processing Record 48 of Set 8 | liverpool
# Processing Record 49 of Set 8 | ulaanbaatar
# Processing Record 50 of Set 8 | monrovia
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | presidencia roque saenz pena
# Processing Record 3 of Set 9 | nogliki
# Processing Record 4 of Set 9 | bubaque
# Processing Record 5 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 9 | khipro
# Processing Record 7 of Set 9 | scarborough
# Processing Record 8 of Set 9 | ukiah
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | phuthaditjhaba
# Processing Record 11 of Set 9 | kuldiga
# Processing Record 12 of Set 9 | tuatapere
# Processing Record 13 of Set 9 | finschhafen
# Processing Record 14 of Set 9 | gwadar
# Processing Record 15 of Set 9 | chicama
# Processing Record 16 of Set 9 | vestmannaeyjar
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | zhangjiakou
# Processing Record 19 of Set 9 | okhotsk
# Processing Record 20 of Set 9 | gudari
# Processing Record 21 of Set 9 | fukue
# Processing Record 22 of Set 9 | topolobampo
# Processing Record 23 of Set 9 | miandrivazo
# Processing Record 24 of Set 9 | harnosand
# Processing Record 25 of Set 9 | baie-comeau
# Processing Record 26 of Set 9 | anadyr
# Processing Record 27 of Set 9 | xining
# Processing Record 28 of Set 9 | raska
# Processing Record 29 of Set 9 | lewistown
# Processing Record 30 of Set 9 | viedma
# Processing Record 31 of Set 9 | takhtamygda
# Processing Record 32 of Set 9 | kefamenanu
# Processing Record 33 of Set 9 | manzanillo
# Processing Record 34 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 35 of Set 9 | mata grande
# Processing Record 36 of Set 9 | buala
# Processing Record 37 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 9 | makakilo city
# Processing Record 39 of Set 9 | cabo san lucas
# Processing Record 40 of Set 9 | presque isle
# Processing Record 41 of Set 9 | taltal
# Processing Record 42 of Set 9 | sal rei
# Processing Record 43 of Set 9 | nago
# Processing Record 44 of Set 9 | paita
# Processing Record 45 of Set 9 | waipawa
# Processing Record 46 of Set 9 | bar harbor
# Processing Record 47 of Set 9 | porto novo
# Processing Record 48 of Set 9 | bandipur
# Processing Record 49 of Set 9 | demak
# Processing Record 50 of Set 9 | katherine
# Processing Record 1 of Set 10 | goderich
# Processing Record 2 of Set 10 | lidkoping
# Processing Record 3 of Set 10 | bayangol
# Processing Record 4 of Set 10 | luderitz
# Processing Record 5 of Set 10 | la ronge
# Processing Record 6 of Set 10 | cidreira
# Processing Record 7 of Set 10 | manchester
# Processing Record 8 of Set 10 | snasa
# Processing Record 9 of Set 10 | gao
# Processing Record 10 of Set 10 | beira
# Processing Record 11 of Set 10 | menomonie
# Processing Record 12 of Set 10 | beloha
# Processing Record 13 of Set 10 | ketchikan
# Processing Record 14 of Set 10 | margate
# Processing Record 15 of Set 10 | mandera
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | camabatela
# Processing Record 18 of Set 10 | wapi pathum
# Processing Record 19 of Set 10 | ancud
# Processing Record 20 of Set 10 | manokwari
# Processing Record 21 of Set 10 | save
# Processing Record 22 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 10 | terre haute
# Processing Record 24 of Set 10 | kualakapuas
# Processing Record 25 of Set 10 | sitka
# Processing Record 26 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 10 | fort nelson
# Processing Record 28 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 10 | victoria
# Processing Record 30 of Set 10 | witney
# Processing Record 31 of Set 10 | nemuro
# Processing Record 32 of Set 10 | bengkulu
# Processing Record 33 of Set 10 | gamba
# Processing Record 34 of Set 10 | kokopo
# Processing Record 35 of Set 10 | madimba
# Processing Record 36 of Set 10 | palmer
# Processing Record 37 of Set 10 | beyla
# Processing Record 38 of Set 10 | port blair
# Processing Record 39 of Set 10 | camachile
# Processing Record 40 of Set 10 | scottsbluff
# Processing Record 41 of Set 10 | svetlaya
# Processing Record 42 of Set 10 | mahebourg
# Processing Record 43 of Set 10 | seydi
# Processing Record 44 of Set 10 | chepareria
# Processing Record 45 of Set 10 | jinchang
# Processing Record 46 of Set 10 | pozo colorado
# Processing Record 47 of Set 10 | nikko
# Processing Record 48 of Set 10 | berdigestyakh
# Processing Record 49 of Set 10 | sorland
# Processing Record 50 of Set 10 | bantou
# Processing Record 1 of Set 11 | kuusamo
# Processing Record 2 of Set 11 | santa maria
# Processing Record 3 of Set 11 | goianesia
# Processing Record 4 of Set 11 | prado
# Processing Record 5 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 11 | hamilton
# Processing Record 7 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 11 | chipinge
# Processing Record 9 of Set 11 | poco branco
# Processing Record 10 of Set 11 | la grande
# Processing Record 11 of Set 11 | latung
# Processing Record 12 of Set 11 | maniitsoq
# Processing Record 13 of Set 11 | sakakah
# Processing Record 14 of Set 11 | corinto
# Processing Record 15 of Set 11 | deniliquin
# Processing Record 16 of Set 11 | meulaboh
# Processing Record 17 of Set 11 | papara
# Processing Record 18 of Set 11 | dzhebariki-khaya
# Processing Record 19 of Set 11 | baghdad
# Processing Record 20 of Set 11 | buin
# Processing Record 21 of Set 11 | grand gaube
# Processing Record 22 of Set 11 | kahului
# Processing Record 23 of Set 11 | northam
# Processing Record 24 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 11 | hambantota
# Processing Record 27 of Set 11 | lazaro cardenas
# Processing Record 28 of Set 11 | alushta
# Processing Record 29 of Set 11 | zabol
# Processing Record 30 of Set 11 | le port
# Processing Record 31 of Set 11 | camacha
# Processing Record 32 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 11 | fare
# Processing Record 34 of Set 11 | alofi
# Processing Record 35 of Set 11 | murray bridge
# Processing Record 36 of Set 11 | shakawe
# Processing Record 37 of Set 11 | lorengau
# Processing Record 38 of Set 11 | kamloops
# Processing Record 39 of Set 11 | valparaiso
# Processing Record 40 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 11 | saldanha
# Processing Record 42 of Set 11 | storforshei
# Processing Record 43 of Set 11 | kyshtovka
# Processing Record 44 of Set 11 | kanchanaburi
# Processing Record 45 of Set 11 | huilong
# Processing Record 46 of Set 11 | sao filipe
# Processing Record 47 of Set 11 | rudnyy
# Processing Record 48 of Set 11 | lompoc
# Processing Record 49 of Set 11 | leshukonskoye
# Processing Record 50 of Set 11 | hede
# Processing Record 1 of Set 12 | zhigansk
# Processing Record 2 of Set 12 | port hedland
# Processing Record 3 of Set 12 | sungaipenuh
# Processing Record 4 of Set 12 | agua dulce
# Processing Record 5 of Set 12 | broken hill
# Processing Record 6 of Set 12 | cascais
# Processing Record 7 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 8 of Set 12 | nyurba
# Processing Record 9 of Set 12 | port hawkesbury
# Processing Record 10 of Set 12 | vicuna
# Processing Record 11 of Set 12 | asyut
# Processing Record 12 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 12 | krasnoselkup
# Processing Record 14 of Set 12 | faratsiho
# Processing Record 15 of Set 12 | hasaki
# Processing Record 16 of Set 12 | kauhajoki
# Processing Record 17 of Set 12 | lubao
# Processing Record 18 of Set 12 | guerrero negro
# Processing Record 19 of Set 12 | vanavara
# Processing Record 20 of Set 12 | valdemarpils
# Processing Record 21 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 22 of Set 12 | nicoya
# Processing Record 23 of Set 12 | suez
# Processing Record 24 of Set 12 | kendari
# Processing Record 25 of Set 12 | kapuskasing
# Processing Record 26 of Set 12 | kimbe
# Processing Record 27 of Set 12 | grindavik
# Processing Record 28 of Set 12 | mabaruma
# Processing Record 29 of Set 12 | avera
# Processing Record 30 of Set 12 | talaya
# Processing Record 31 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 12 | urambo
# Processing Record 33 of Set 12 | praia da vitoria
# Processing Record 34 of Set 12 | quilmana
# Processing Record 35 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 12 | issoudun
# Processing Record 37 of Set 12 | pasighat
# Processing Record 38 of Set 12 | coihaique
# Processing Record 39 of Set 12 | jaramana
# City not found. Skipping...
# Processing Record 40 of Set 12 | basarabeasca
# Processing Record 41 of Set 12 | atambua
# Processing Record 42 of Set 12 | mahanoro
# Processing Record 43 of Set 12 | mandalgovi
# Processing Record 44 of Set 12 | lermontovka
# Processing Record 45 of Set 12 | toora-khem
# Processing Record 46 of Set 12 | nioro
# Processing Record 47 of Set 12 | tautira
# Processing Record 48 of Set 12 | aden
# Processing Record 49 of Set 12 | hirara
# Processing Record 50 of Set 12 | touros
# Processing Record 1 of Set 13 | phetchabun
# Processing Record 2 of Set 13 | biloela
# Processing Record 3 of Set 13 | koungheul
# Processing Record 4 of Set 13 | karwar
# Processing Record 5 of Set 13 | artyom
# Processing Record 6 of Set 13 | port hardy
# Processing Record 7 of Set 13 | srednekolymsk
# Processing Record 8 of Set 13 | muromtsevo
# Processing Record 9 of Set 13 | jackson
# Processing Record 10 of Set 13 | celestun
# Processing Record 11 of Set 13 | malanje
# Processing Record 12 of Set 13 | houma
# Processing Record 13 of Set 13 | mogadishu
# Processing Record 14 of Set 13 | xuddur
# Processing Record 15 of Set 13 | tucurui
# Processing Record 16 of Set 13 | emba
# Processing Record 17 of Set 13 | honningsvag
# Processing Record 18 of Set 13 | rovaniemi
# Processing Record 19 of Set 13 | ruidoso
# Processing Record 20 of Set 13 | brae
# Processing Record 21 of Set 13 | caucasia
# Processing Record 22 of Set 13 | coos bay
# Processing Record 23 of Set 13 | merritt island
# Processing Record 24 of Set 13 | killybegs
# Processing Record 25 of Set 13 | meadow lake
# Processing Record 26 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 13 | pak chong
# Processing Record 28 of Set 13 | lampa
# Processing Record 29 of Set 13 | praya
# Processing Record 30 of Set 13 | senador pompeu
# Processing Record 31 of Set 13 | moroto
# Processing Record 32 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 13 | abalak
# Processing Record 34 of Set 13 | tessalit
# Processing Record 35 of Set 13 | bella union
# Processing Record 36 of Set 13 | cururupu
# Processing Record 37 of Set 13 | pacific grove
# Processing Record 38 of Set 13 | plastun
# Processing Record 39 of Set 13 | joplin
# Processing Record 40 of Set 13 | mananjary
# Processing Record 41 of Set 13 | nuuk
# Processing Record 42 of Set 13 | centralia
# Processing Record 43 of Set 13 | pocos de caldas
# Processing Record 44 of Set 13 | valenca
# Processing Record 45 of Set 13 | zhirnovsk
# Processing Record 46 of Set 13 | svetlyy
# Processing Record 47 of Set 13 | mezen
# Processing Record 48 of Set 13 | lagos
# Processing Record 49 of Set 13 | atar
# Processing Record 50 of Set 13 | smithers
# Processing Record 1 of Set 14 | del carmen
# Processing Record 2 of Set 14 | luanda
# Processing Record 3 of Set 14 | merke
# Processing Record 4 of Set 14 | rocha
# Processing Record 5 of Set 14 | sambava
# Processing Record 6 of Set 14 | dalby
# Processing Record 7 of Set 14 | arlit
# Processing Record 8 of Set 14 | birobidzhan
# Processing Record 9 of Set 14 | qinggang
# Processing Record 10 of Set 14 | grand baie
# Processing Record 11 of Set 14 | tevriz
# Processing Record 12 of Set 14 | monte azul
# Processing Record 13 of Set 14 | torres
# Processing Record 14 of Set 14 | walvis bay
# Processing Record 15 of Set 14 | mitsamiouli
# Processing Record 16 of Set 14 | bolgatanga
# Processing Record 17 of Set 14 | kushima
# Processing Record 18 of Set 14 | saint-augustin
# Processing Record 19 of Set 14 | kota belud
# Processing Record 20 of Set 14 | nhulunbuy
# Processing Record 21 of Set 14 | muzhi
# Processing Record 22 of Set 14 | maarianhamina
# Processing Record 23 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 14 | kamina
# Processing Record 25 of Set 14 | laramie
# Processing Record 26 of Set 14 | antalaha
# Processing Record 27 of Set 14 | kyra
# Processing Record 28 of Set 14 | verkhnyaya inta
# Processing Record 29 of Set 14 | bonthe
# Processing Record 30 of Set 14 | kabinda
# Processing Record 31 of Set 14 | mufulira
# Processing Record 32 of Set 14 | lakes entrance
# Processing Record 33 of Set 14 | honiara
# Processing Record 34 of Set 14 | comodoro rivadavia
# Processing Record 35 of Set 14 | kon tum
# Processing Record 36 of Set 14 | taiping
# Processing Record 37 of Set 14 | nelson bay
# Processing Record 38 of Set 14 | nanuque
# Processing Record 39 of Set 14 | curup
# Processing Record 40 of Set 14 | hammerfest
# Processing Record 41 of Set 14 | dingle
# Processing Record 42 of Set 14 | collie
# Processing Record 43 of Set 14 | wanning
# Processing Record 44 of Set 14 | nanyamba
# Processing Record 45 of Set 14 | mapimi
# Processing Record 46 of Set 14 | sao felix do xingu
# Processing Record 47 of Set 14 | yerbogachen
# Processing Record 48 of Set 14 | tansen
# Processing Record 49 of Set 14 | jacmel
# Processing Record 50 of Set 14 | tromso
# Processing Record 1 of Set 15 | newark
# Processing Record 2 of Set 15 | novopokrovka
# Processing Record 3 of Set 15 | jalu
# Processing Record 4 of Set 15 | okha
# Processing Record 5 of Set 15 | tiarei
# Processing Record 6 of Set 15 | parabel
# Processing Record 7 of Set 15 | oranjemund
# Processing Record 8 of Set 15 | tobermory
# Processing Record 9 of Set 15 | new glasgow
# Processing Record 10 of Set 15 | hailey
# Processing Record 11 of Set 15 | nehe
# Processing Record 12 of Set 15 | vasteras
# Processing Record 13 of Set 15 | banjar
# Processing Record 14 of Set 15 | yorosso
# Processing Record 15 of Set 15 | lavrentiya
# Processing Record 16 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 15 | mandi bahauddin
# Processing Record 18 of Set 15 | quelimane
# Processing Record 19 of Set 15 | magadi
# Processing Record 20 of Set 15 | havoysund
# Processing Record 21 of Set 15 | tateyama
# Processing Record 22 of Set 15 | daoukro
# Processing Record 23 of Set 15 | vila velha
# Processing Record 24 of Set 15 | sandy bay
# Processing Record 25 of Set 15 | jonesboro
# Processing Record 26 of Set 15 | wegrow
# Processing Record 27 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 29 of Set 15 | sassandra
# Processing Record 30 of Set 15 | elmadag
# Processing Record 31 of Set 15 | bintulu
# Processing Record 32 of Set 15 | la rioja
# Processing Record 33 of Set 15 | manica
# Processing Record 34 of Set 15 | asadabad
# Processing Record 35 of Set 15 | mapulot
# Processing Record 36 of Set 15 | buchanan
# Processing Record 37 of Set 15 | galle
# Processing Record 38 of Set 15 | hualmay
# Processing Record 39 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | matamoros
# Processing Record 41 of Set 15 | mujiayingzi
# Processing Record 42 of Set 15 | morton
# Processing Record 43 of Set 15 | bereda
# Processing Record 44 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 15 | altamont
# Processing Record 46 of Set 15 | guantanamo
# Processing Record 47 of Set 15 | orchard homes
# Processing Record 48 of Set 15 | redlands
# Processing Record 49 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 15 | ambon
# Processing Record 1 of Set 16 | kieta
# Processing Record 2 of Set 16 | santa elena
# Processing Record 3 of Set 16 | naifaru
# Processing Record 4 of Set 16 | maimon
# City not found. Skipping...
# Processing Record 5 of Set 16 | korhogo
# Processing Record 6 of Set 16 | susehri
# Processing Record 7 of Set 16 | laguna
# Processing Record 8 of Set 16 | tashtyp
# Processing Record 9 of Set 16 | letka
# Processing Record 10 of Set 16 | ballina
# Processing Record 11 of Set 16 | mongar
# Processing Record 12 of Set 16 | zeya
# Processing Record 13 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 14 of Set 16 | sept-iles
# Processing Record 15 of Set 16 | lata
# Processing Record 16 of Set 16 | male
# Processing Record 17 of Set 16 | nortelandia
# Processing Record 18 of Set 16 | nouadhibou
# Processing Record 19 of Set 16 | bilibino
# Processing Record 20 of Set 16 | zarichne
# Processing Record 21 of Set 16 | tuy hoa
# Processing Record 22 of Set 16 | zhanaozen
# Processing Record 23 of Set 16 | tailai
# Processing Record 24 of Set 16 | basco
# Processing Record 25 of Set 16 | morgan city
# Processing Record 26 of Set 16 | mokrousovo
# Processing Record 27 of Set 16 | kabanjahe
# Processing Record 28 of Set 16 | petrolandia
# City not found. Skipping...
# Processing Record 29 of Set 16 | sobolevo
# Processing Record 30 of Set 16 | cabinda
# Processing Record 31 of Set 16 | ulaangom
# Processing Record 32 of Set 16 | nenjiang
# Processing Record 33 of Set 16 | minot
# Processing Record 34 of Set 16 | university park
# Processing Record 35 of Set 16 | kalispell
# Processing Record 36 of Set 16 | nizhniy baskunchak
# Processing Record 37 of Set 16 | kishtwar
# Processing Record 38 of Set 16 | bageshwar
# Processing Record 39 of Set 16 | galveston
# Processing Record 40 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 41 of Set 16 | xinxiang
# Processing Record 42 of Set 16 | koumac
# Processing Record 43 of Set 16 | arawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Olafsvik  64.8945  -23.7142     40.10        77          93       12.39
# 1  Port Alfred -33.5906   26.8910     60.46        83          22       12.64
# 2         Toma  12.7667   -2.8833     83.34        41          85        7.96
# 3      Rikitea -23.1203 -134.9692     73.74        79          39       19.06
# 4        Kapaa  22.0752 -159.3190     82.72        69          20        4.00
#
#   Country Current Description
# 0      IS     overcast clouds
# 1      ZA          few clouds
# 2      BF     overcast clouds
# 3      PF          light rain
# 4      US          few clouds

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# %%
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Olafsvik      IS  64.8945  -23.7142     40.10        77          93
# 1  Port Alfred      ZA -33.5906   26.8910     60.46        83          22
# 2         Toma      BF  12.7667   -2.8833     83.34        41          85
# 3      Rikitea      PF -23.1203 -134.9692     73.74        79          39
# 4        Kapaa      US  22.0752 -159.3190     82.72        69          20
#
#    Wind Speed Current Description
# 0       12.39     overcast clouds
# 1       12.64          few clouds
# 2        7.96     overcast clouds
# 3       19.06          light rain
# 4        4.00          few clouds

# %%
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Olafsvik      IS  64.8945  -23.7142     40.96        89         100
# 1    Port Alfred      ZA -33.5906   26.8910     55.13        77          29
# 2           Toma      BF  12.7667   -2.8833     83.71        48          42
# 3        Rikitea      PF -23.1203 -134.9692     73.69        63          79
# 4          Kapaa      US  22.0752 -159.3190     80.58        78          90
# ..           ...     ...      ...       ...       ...       ...         ...
# 729    Bageshwar      IN  29.8500   79.7667     64.09        92          13
# 730    Galveston      US  29.3669  -94.9669     88.20        73          20
# 731     Xinxiang      CN  35.3089  113.8672     69.48        89          99
# 732       Koumac      NC -20.5667  164.2833     79.32        72           5
# 733        Arawa      PG  -6.2132  155.5367     83.98        71         100
#
#      Wind Speed Current Description
# 0         32.41     overcast clouds
# 1          7.52     overcast clouds
# 2          6.35     overcast clouds
# 3         15.79     overcast clouds
# 4          5.01     overcast clouds
# ..          ...                 ...
# 729        2.13     overcast clouds
# 730        9.22     overcast clouds
# 731       16.46     overcast clouds
# 732        7.78     overcast clouds
# 733        1.28     overcast clouds
#
# [734 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/dtj13/Documents/Data Analytics Course/Module_6_API/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
